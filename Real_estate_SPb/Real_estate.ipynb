# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Откройте-файл-с-данными-и-изучите-общую-информацию." data-toc-modified-id="Откройте-файл-с-данными-и-изучите-общую-информацию.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Откройте файл с данными и изучите общую информацию.</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Число-фотографий---total_images" data-toc-modified-id="Число-фотографий---total_images-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Число фотографий - total_images</a></span></li><li><span><a href="#Цена-на-момент-снятия-с-публикации---last_price" data-toc-modified-id="Цена-на-момент-снятия-с-публикации---last_price-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Цена на момент снятия с публикации - last_price</a></span></li><li><span><a href="#Общая-площадь-квартиры---total_area" data-toc-modified-id="Общая-площадь-квартиры---total_area-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Общая площадь квартиры - total_area</a></span></li><li><span><a href="#Дата-публикации---first_day_exposition" data-toc-modified-id="Дата-публикации---first_day_exposition-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Дата публикации - first_day_exposition</a></span></li><li><span><a href="#Количество-комнат---rooms" data-toc-modified-id="Количество-комнат---rooms-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Количество комнат - rooms</a></span></li><li><span><a href="#Высота-потолков---ceiling_height" data-toc-modified-id="Высота-потолков---ceiling_height-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Высота потолков - ceiling_height</a></span></li><li><span><a href="#Всего-этажей-в-доме---floors_total" data-toc-modified-id="Всего-этажей-в-доме---floors_total-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Всего этажей в доме - floors_total</a></span></li><li><span><a href="#Жилая-площадь---living_area" data-toc-modified-id="Жилая-площадь---living_area-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Жилая площадь - living_area</a></span></li><li><span><a href="#Апартаменты---is_apartment" data-toc-modified-id="Апартаменты---is_apartment-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Апартаменты - is_apartment</a></span></li><li><span><a href="#Квартира-студия---studio" data-toc-modified-id="Квартира-студия---studio-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Квартира-студия - studio</a></span></li><li><span><a href="#Cвободная-планировка---open_plan" data-toc-modified-id="Cвободная-планировка---open_plan-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Cвободная планировка - open_plan</a></span></li><li><span><a href="#Площадь-кухни---kitchen_area" data-toc-modified-id="Площадь-кухни---kitchen_area-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Площадь кухни - kitchen_area</a></span></li><li><span><a href="#Число-балконов---balcony" data-toc-modified-id="Число-балконов---balcony-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Число балконов - balcony</a></span></li><li><span><a href="#Название-населённого-пункта---locality_name" data-toc-modified-id="Название-населённого-пункта---locality_name-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Название населённого пункта - locality_name</a></span></li><li><span><a href="#Расстояние-до-ближайшего-аэропорта-в-метрах-(м)---airports_nearest" data-toc-modified-id="Расстояние-до-ближайшего-аэропорта-в-метрах-(м)---airports_nearest-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Расстояние до ближайшего аэропорта в метрах (м) - airports_nearest</a></span></li><li><span><a href="#Расстояние-до-центра-города-(м)---city_centers_nearest" data-toc-modified-id="Расстояние-до-центра-города-(м)---city_centers_nearest-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>Расстояние до центра города (м) - city_centers_nearest</a></span></li><li><span><a href="#Число-парков-в-радиусе-3-км---parks_around_3000" data-toc-modified-id="Число-парков-в-радиусе-3-км---parks_around_3000-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>Число парков в радиусе 3 км - parks_around_3000</a></span></li><li><span><a href="#Расстояние-до-ближайшего-парка-(м)---parks_nearest" data-toc-modified-id="Расстояние-до-ближайшего-парка-(м)---parks_nearest-2.18"><span class="toc-item-num">2.18&nbsp;&nbsp;</span>Расстояние до ближайшего парка (м) - parks_nearest</a></span></li><li><span><a href="#Число-водоёмов-в-радиусе-3-км---ponds_around_3000" data-toc-modified-id="Число-водоёмов-в-радиусе-3-км---ponds_around_3000-2.19"><span class="toc-item-num">2.19&nbsp;&nbsp;</span>Число водоёмов в радиусе 3 км - ponds_around_3000</a></span></li><li><span><a href="#Расстояние-до-ближайшего-водоёма-(м)---ponds_nearest" data-toc-modified-id="Расстояние-до-ближайшего-водоёма-(м)---ponds_nearest-2.20"><span class="toc-item-num">2.20&nbsp;&nbsp;</span>Расстояние до ближайшего водоёма (м) - ponds_nearest</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.21"><span class="toc-item-num">2.21&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Посчитайте-и-добавьте-в-таблицу-новые-столбцы" data-toc-modified-id="Посчитайте-и-добавьте-в-таблицу-новые-столбцы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Посчитайте и добавьте в таблицу новые столбцы</a></span><ul class="toc-item"><li><span><a href="#Добавим-колонку-с-ценой-одного-квадратного-метра" data-toc-modified-id="Добавим-колонку-с-ценой-одного-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Добавим колонку с ценой одного квадратного метра</a></span></li><li><span><a href="#Добавим-колонки-с-годом,-месяцем-и-днем-размещения-объявления" data-toc-modified-id="Добавим-колонки-с-годом,-месяцем-и-днем-размещения-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Добавим колонки с годом, месяцем и днем размещения объявления</a></span></li><li><span><a href="#Добавим-колонку-с-типом-этажа-объекта" data-toc-modified-id="Добавим-колонку-с-типом-этажа-объекта-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Добавим колонку с типом этажа объекта</a></span></li><li><span><a href="#Добавим-колонку-с-расстоянием-от-центра-города-в-км" data-toc-modified-id="Добавим-колонку-с-расстоянием-от-центра-города-в-км-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Добавим колонку с расстоянием от центра города в км</a></span></li></ul></li><li><span><a href="#Проведите-исследовательский-анализ-данных" data-toc-modified-id="Проведите-исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Проведите исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Продолжительность-размещения-объявления-days_exposition" data-toc-modified-id="Продолжительность-размещения-объявления-days_exposition-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Продолжительность размещения объявления days_exposition</a></span></li><li><span><a href="#Зависимость-цены-от-общей-площади-квартиры" data-toc-modified-id="Зависимость-цены-от-общей-площади-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Зависимость цены от общей площади квартиры</a></span></li><li><span><a href="#Зависимость-цены-от-жилой-площади-квартиры" data-toc-modified-id="Зависимость-цены-от-жилой-площади-квартиры-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Зависимость цены от жилой площади квартиры</a></span></li><li><span><a href="#Зависимость-цены-от-площади-кухни" data-toc-modified-id="Зависимость-цены-от-площади-кухни-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Зависимость цены от площади кухни</a></span></li><li><span><a href="#Зависимость-цены-от-количества-комнат" data-toc-modified-id="Зависимость-цены-от-количества-комнат-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Зависимость цены от количества комнат</a></span></li><li><span><a href="#Зависимость-цены-от-типа-этажа-квартиры" data-toc-modified-id="Зависимость-цены-от-типа-этажа-квартиры-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Зависимость цены от типа этажа квартиры</a></span></li><li><span><a href="#Зависимость-цены-от-даты-размещения" data-toc-modified-id="Зависимость-цены-от-даты-размещения-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Зависимость цены от даты размещения</a></span></li><li><span><a href="#Цена-квадратного-метра-в-зависимости-от-населенного-пункта" data-toc-modified-id="Цена-квадратного-метра-в-зависимости-от-населенного-пункта-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Цена квадратного метра в зависимости от населенного пункта</a></span></li><li><span><a href="#Средняя-цена-км-по-удаленности-от-центра-города" data-toc-modified-id="Средняя-цена-км-по-удаленности-от-центра-города-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Средняя цена км по удаленности от центра города</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

try:
     data = pd.read_csv(r"C:\Проекты Яндекс.Практикум\3. Исследовательский анализ данных. Объявления о продаже квартир\Датасет\real_estate_data.csv", sep = '\t')
except: 
    data = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')
    
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# Открыли датасет, использую разделитель. При первой попытке открытия данные были склеены. В таблице 22 колонки с параметрами объектов. Есть пропущенные значения.

# %%
data.hist(figsize=(15, 20))

plt.show()

# %% [markdown]
# По 17 параметрам удалось постоить гистрограммы. Есть параметры, у которых всего несколько значений, что вполне логично: балконы, количество парков в радиусе 3 км, количество прудов в радиусе 3 км. Некоторые гистограммы требуют изменения параметров, для более детального рассмотрения. Например, мало информативен один высокий столбик в графике last_price.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Изучим общую информацию о таблице:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Есть столбцы с пропущенными знаничениями. По наиболее важным параметров пропусков меньше или вовсе нет, по менее важным - пропусков больше. Бросился в глаза тип данныx object  в параметре  first_day_exposition, его нужно будет поменять на datetime
#
# Так как параметров много и легко запутаться, будет изучать их по порядку. Проводя предобработку и исследовательский анализ параметра сразу

# %% [markdown]
# #### Число фотографий - total_images

# %%
data['total_images'].hist()

plt.xlabel('Число фотографий')
plt.ylabel('Количество объявлений')
plt.title('Распределение числа фотографий')
plt.show()

# %% [markdown]
# В параметре total_images нет пропущенных значений и гистрорамма не вызывает вопросов. Среднее количество фотограий около 10. Оставим это  столбцев без изменений

# %% [markdown]
# #### Цена на момент снятия с публикации - last_price

# %%
data['last_price'].hist(bins=100)

plt.xlabel('Цена на момент снятия с публикации')
plt.ylabel('Количество объявлений')
plt.title('Распределение последней цены')
plt.show()

# %% [markdown]
# Пропусков нет, но гистрограмма не информативна, изменим параметры, чтобы изучить более детально

# %%
data['last_price'].hist(bins = 10, range=(0, 10000000))

plt.xlabel('Цена на момент снятия с публикации')
plt.ylabel('Количество объявлений')
plt.title('Распределение последней цены')
plt.show()

# %% [markdown]
# Использовав параметр range от 0 до 100 млн, видим, что есть пик на цене примерно 35 млн, после которого идет плавное снижение. При этом не ясны минимальное и максимальное значение

# %%
data.boxplot('last_price')

plt.ylabel('Цена на момент снятия с публикации')
plt.title('Диаграмма размаха последней цены')
plt.show()

# %%
data['last_price'].describe()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Поситроили диаграмму размаха и вывели описание столбца. Минимальная цена 12 тыс выглядит нереалистичной. Максимальная 763 млн далеко отступает от остальных дорогих квартир (примерно на 350 млн). Минимальная и максимальная цены требуют проверки. Оба этих показателя влияют на большое различие между средней и медианной ценой. 6,5 млн и 4,6 млн соответственно.

# %%
data.query('last_price < 500000').sort_values(by = 'last_price')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 8793              7     12190.0       109.0  2019-03-20T00:00:00      2
# 14911             5    430000.0        54.0  2018-06-26T00:00:00      2
# 17456             7    430000.0        30.4  2019-04-22T00:00:00      1
# 16274            18    440000.0        40.0  2018-07-10T00:00:00      1
# 5698              7    450000.0        42.0  2017-07-31T00:00:00      2
# 9581              7    450000.0        43.4  2018-08-31T00:00:00      2
# 16219            14    450000.0        38.5  2018-07-11T00:00:00      2
# 17676             0    450000.0        36.5  2018-02-01T00:00:00      1
# 18867             1    470000.0        41.0  2018-02-11T00:00:00      1
# 21912             0    470000.0        37.0  2018-02-18T00:00:00      1
# 23484            11    470000.0        44.5  2018-07-02T00:00:00      2
# 16032             8    480000.0        32.0  2019-01-06T00:00:00      1
# ...

# %%
data.query('last_price > 450000000').sort_values(by = 'last_price')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 12971            19  763000000.0       400.0  2017-09-30T00:00:00      7
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 12971             NaN          10.0        250.0     10          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 12971           NaN      2.0  Санкт-Петербург           25108.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 12971              3956.0               1.0          530.0               3.0
#
#        ponds_nearest  days_exposition
# 12971          756.0             33.0
#
# [1 rows x 22 columns]

# %% [markdown]
# Изучили срез квартир стоиомстью до 500 тыс. Очень дешевая квартира за 12 тыс - одна (остальные стоят от 430 тыс). У нее 2 комнаты, общая площадь 109 кв м. Можно предположить, что цена на самом деле 12 млн. Или это цена за кв м. Но не будем додумывать, от одной квартиры можно и избавиться
#
# В квартире за  763 млн 7 комнат, жилая пл - 250 м кв, находится в 3956 м от центра города, то есть в хорошем районе, а на Авито есть квартиры со столь же высокими ценами. Поэтому считаем, что эта квартира реальная.
#
# Перезапишем датасет, исключив их него квартиру за 12 тыс и двинемся дальше

# %%
data = data[data['last_price'] != 12190.0]

# %% [markdown]
# #### Общая площадь квартиры - total_area

# %%
data['total_area'].hist(bins = 200)

plt.xlabel('Общая площадь')
plt.ylabel('Количество объявлений')
plt.title('Распределение общей площади')
plt.show()

# %%
data['total_area'].describe()
# Out:
# count    23698.000000
# mean        60.346598
# std         35.653434
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.875000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Пропусков нет. Медианное значение 52 кв м, среднее 60 кв м. Минимальное 12 кв м, к сожалению, может быть правдой. 75% - 69 кв м. Максимум 900 кв м и да , это реально.
#
# Из гистрограммы видно, что примерно после 100 кв м квартир значительно меньше. А после 200 кв м квартир практически нет
#
# Проверим сколько стоят и где находятся самая маленькая и большая квартиры, чтобы убедиться в правдоподобности

# %%
data.query('total_area == 12')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 19904             4   2400000.0        12.0  2017-07-19T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 19904            2.55           5.0         10.0      2          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 19904           NaN      NaN  Санкт-Петербург           21314.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 19904               964.0               1.0          886.0               2.0
#
#        ponds_nearest  days_exposition
# 19904           45.0            200.0
#
# [1 rows x 22 columns]

# %% [markdown]
# Выглядит реально. Центр Петербурга (964 метра от центра), жилая площадь 10 кв м, цена 2 400 000. Оставляем, как есть

# %%
data.query('total_area == 900')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 19540             8  420000000.0       900.0  2017-12-06T00:00:00     12
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 19540             2.8          25.0        409.7     25          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 19540         112.0      NaN  Санкт-Петербург           30706.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 19540              7877.0               0.0            NaN               2.0
#
#        ponds_nearest  days_exposition
# 19540          318.0            106.0
#
# [1 rows x 22 columns]

# %% [markdown]
# 420 млн, 12 комнат. При этом из 900 м, жилые только 409 м и еще 112 м - кухня. Получается больше половины - нежилая часть.

# %% [markdown]
# #### Дата публикации - first_day_exposition

# %% [markdown]
# **first_day_exposition**. Нет пропущенных значений, но тип данных object  надо поменять на datetime, чтобы в дальнейшем было удобнее работать. Сейчас время указано  в таком формате : 2018-06-19 00:00:00

# %%
data['first_day_exposition'] = data['first_day_exposition'].astype("datetime64")

# %%
pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%d %H:%M:%S')
# Out:
# 0       2019-03-07
# 1       2018-12-04
# 2       2015-08-20
# 3       2015-07-24
# 4       2018-06-19
#            ...
# 23694   2017-03-21
# 23695   2018-01-15
# 23696   2018-02-11
# 23697   2017-03-28
# 23698   2017-07-21
# Name: first_day_exposition, Length: 23698, dtype: datetime64[ns]

# %%
data['first_day_exposition'].min()
# Out:
# Timestamp('2014-11-27 00:00:00')

# %%
data['first_day_exposition'].max()
# Out:
# Timestamp('2019-05-03 00:00:00')

# %% [markdown]
# Посмотрели минимальное и максимальное значение - в датасете объявления примерно за 5 лет

# %% [markdown]
# #### Количество комнат - rooms

# %%
data['rooms'].hist(bins = 50)

plt.xlabel('Количество комнат')
plt.ylabel('Количество объявлений')
plt.title('Распределение количества комнат')
plt.show()

# %%
data['rooms'].describe()
# Out:
# count    23698.000000
# mean         2.070639
# std          1.078428
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Пропусков нет. Среднее и медианное количество комнат = 2. 75% - 3 комнаты. Из гистораммы и описания видно, что есть какое-то небольшое количество квартир с 0 комнат, скорее всего студии, но надо проверить.

# %%
data.pivot_table(index = 'rooms', values = 'studio')
# Out:
#          studio
# rooms
# 0      0.700508
# 1      0.001367
# 2      0.000000
# 3      0.000000
# 4      0.000000
# 5      0.000000
# 6      0.000000
# 7      0.000000
# 8      0.000000
# 9      0.000000
# 10     0.000000
# 11     0.000000
# 12     0.000000
# 14     0.000000
# 15     0.000000
# 16     0.000000
# 19     0.000000

# %% [markdown]
# Большинство квартир с 0 комнат - это студии. Проверим также квартиры с очень большим количеством комнат:

# %%
data.query('rooms > 10').sort_values('rooms')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 648               3   17500000.0       183.7           2018-07-01     11
# 9688              8   33000000.0       194.1           2017-02-07     11
# 19540             8  420000000.0       900.0           2017-12-06     12
# 866               5   25000000.0       363.0           2017-12-23     14
# 20829             6   28659000.0       245.4           2016-03-31     14
# 5358             20   65000000.0       590.0           2019-02-14     15
# 18848             6   28500000.0       270.0           2015-03-02     16
# 14498             6   32250000.0       374.6           2018-06-09     19
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 648              3.40           7.0        138.8      7          NaN  ...
# 9688             3.43           5.0        129.0      2          NaN  ...
# 19540            2.80          25.0        409.7     25          NaN  ...
# ...

# %% [markdown]
# В квартире с 19 комнатами площадь 374 метра, 3 км от центра и цена 32 млн. Похоже квартиру в доходном доме, которая была коммуналкой.  Так как сделали срез по квартирам от 10 комнат, то видим, что все 8 квартир почти в центре и с большой площадью. Можем допустить реальность данных
#
# На последок проверим, что среди комнат не было значений типа 2.2 комнаты

# %%
rooms_integer = data['rooms'] - np.floor( data['rooms'] )  > 0
rooms_integer.value_counts()
# Out:
# False    23698
# Name: rooms, dtype: int64

# %% [markdown]
# Значения корректные

# %% [markdown]
# #### Высота потолков - ceiling_height

# %% [markdown]
# Пропущенных значений около 9 тыс. Почти 40%. Вряд ли высота потолка имеет одно из важных значений.Но посмотрим, какие значения есть

# %%
data['ceiling_height'].describe()
# Out:
# count    14503.000000
# mean         2.771500
# std          1.261099
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].hist(bins = 50, range=(10,100))

plt.xlabel('Высотка потолков')
plt.ylabel('Количество объявлений')
plt.title('Распределение высоты потолков')
plt.show()

# %% [markdown]
# Максимальное значение 100 метров не реалестично. Гистрограмма также показывает какие-то квартиры с птолками по 20 метров. Изучим срез по квартирам от 10 метров

# %%
data.query('ceiling_height > 10').sort_values('ceiling_height')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22309            20   5300000.0        45.0           2017-09-30      1
# 15061            19   5600000.0        56.4           2018-05-11      2
# 17496            15   6700000.0        92.9           2019-02-19      3
# 20507            12   5950000.0        60.0           2018-02-19      2
# 5076              0   3850000.0        30.5           2018-10-03      1
# 355              17   3600000.0        55.2           2018-07-12      2
# 18545             6   3750000.0        43.0           2019-03-18      2
# 11285             0   1950000.0        37.0           2019-03-20      1
# 9379              5   3950000.0        42.0           2017-03-26      3
# 14382             9   1700000.0        35.0           2015-12-04      1
# 4643              0   4300000.0        45.0           2018-02-01      2
# 6246              6   3300000.0        44.4           2019-03-25      2
# ...

# %% [markdown]
# Как было подсказано в описании задачи скорее всего 25 метро - это 2.5 метра. Разделим на 10 высоту потолков более 14 метров

# %%
max_ceiling_height = 14
q_ceiling_is_too_high = data.ceiling_height > max_ceiling_height
data.loc[q_ceiling_is_too_high, "ceiling_height"] = data.loc[q_ceiling_is_too_high, "ceiling_height"] / 10

# %%
data['ceiling_height'].describe()
# Out:
# count    14503.000000
# mean         2.729606
# std          0.319861
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max         14.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Вывели обновленное описание столбца, корректировка почти не отразилась на медиане и среднем

# %% [markdown]
# Пропущенные значения заполним медианой:

# %%
median_ceiling = data['ceiling_height'].median()
data['ceiling_height'] = data['ceiling_height'].fillna(median_ceiling)

# %% [markdown]
# #### Всего этажей в доме - floors_total

# %% [markdown]
# Пропущено около 80 значений. Не будем удалять строки с пропусками, т к количество этажей не столь важный фактор. Мы заранее решили, что будем делить квартиры по типу этажа: первый, последний, другой. Но все же проверим, какие есть значения

# %%
data['floors_total'].describe()
# Out:
# count    23612.000000
# mean        10.673217
# std          6.596654
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# Максимальное количество этажей - 60. Загуглили, что самое высокое жилое здание в Петербурге - ЖК Князь Александр Невский, у которого 37 этажей. Сделаем срез по зданиям выше 37 этажей

# %%
data.query('floors_total > 37').sort_values('floors_total')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 16731             9   3978000.0        40.0           2018-09-24      1
# 2253             12   3800000.0        45.5           2018-06-28      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 16731            2.65          52.0         10.5     18          NaN  ...
# 2253             2.88          60.0         27.4      4          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 16731          14.0      NaN  Санкт-Петербург           20728.0
# 2253            7.4      NaN        Кронштадт           67763.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 16731             12978.0               1.0          793.0               0.0
# 2253              49488.0               2.0          342.0               3.0
#
#        ponds_nearest  days_exposition
# 16731            NaN             45.0
# ...

# %% [markdown]
# Два здания, а 60-метровое в Кронштадте. Выглядит неправдоподобно. Даже на 10 разделить, т к второе здание 52  - не может быть 5.2 этажей. Можно заменить значения этажности здания в этих строках на Nan

# %%
data.loc[2253,'floors_total'] = None
data.loc[16731,'floors_total'] = None
data['floors_total'].describe()
# Out:
# count    23610.000000
# mean        10.669377
# std          6.583625
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         37.000000
# Name: floors_total, dtype: float64

# %% [markdown]
# На последок убедимся, что значения этажей целые числа по смыслку. Что нет этажа 5.5 , например. Так как из-за пропусков в значениях перевести float  в int  не получится. Отбросим дробную часть и проверим есть ли разница между тем, что было и тем, что стало

# %%
floors_total_integer = data['floors_total'] - np.floor( data['floors_total'] )  > 0
floors_total_integer.value_counts()
# Out:
# False    23698
# Name: floors_total, dtype: int64

# %% [markdown]
# Значения корректные

# %% [markdown]
# #### Жилая площадь - living_area

# %%
data['living_area'].hist()

plt.xlabel('Жилай площадь')
plt.ylabel('Количество объявлений')
plt.title('Распределение жилой площади')
plt.show()

# %%
data['living_area'].describe()
# Out:
# count    21795.000000
# mean        34.457965
# std         22.030944
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Около 1900 пропусков. При этом общая площадь указана у всех объявлений. Может быть связано с тем, что некоторые квартиры - это апартаменты или студии, у которых забиыли в объявлении выделить жилую площадь.
#
# По гистрограмме видно, что квартир с жилой площадью больше 80 кв м совсем мало.
#
# Из описания видно, что средняя и медиана почти равны и составляют около 30 кв м.

# %% [markdown]
# Проверим есть ли жилая площадь больше общей площади, чтобы исключить ошибки

# %%
data[data['living_area'] > data['total_area']]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Таких значений нет

# %% [markdown]
# Найдем медианные значения общей и жилой площадей.

# %%
median_total_area = data['total_area'].median()
median_total_area
# Out:
# 52.0

# %%
median_living_area = data['living_area'].median()
median_living_area
# Out:
# 30.0

# %% [markdown]
# Посчитаем соотношение медианы общей площади к медиане жилой площади

# %%
ratio_median_total_living = median_total_area/median_living_area
ratio_median_total_living
# Out:
# 1.7333333333333334

# %% [markdown]
# Заполним пропуски отношением общей площади к соотношению, найденному выше

# %%
data['living_area'] = data['living_area'].fillna(data['total_area']/ratio_median_total_living)

# %% [markdown]
# Изменим типа данных с float64 на float32 для экономии памяти

# %%
data['living_area']=data['living_area'].astype('float32')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23698 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23698 non-null  int64
#  1   last_price            23698 non-null  float64
#  2   total_area            23698 non-null  float64
#  3   first_day_exposition  23698 non-null  datetime64[ns]
#  4   rooms                 23698 non-null  int64
#  5   ceiling_height        23698 non-null  float64
#  6   floors_total          23610 non-null  float64
#  7   living_area           23698 non-null  float32
#  8   floor                 23698 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23698 non-null  bool
#  11  open_plan             23698 non-null  bool
#  12  kitchen_area          21420 non-null  float64
#  13  balcony               12180 non-null  float64
# ...

# %% [markdown]
# #### Апартаменты - is_apartment

# %% [markdown]
# Около 20 тыс пропусков. В описании задачи указано, что тут должен быть булев тип. Но в info выскочило object . В первых пяти строках data видны только Nan. Посмотрю, какие еще данные есть в этом столбце

# %%
data['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Значения True И  False. Логика верная. Оставлю тип, как есть. Но хочу заполнить пропущенные значения, т к пропусков слишком много. Если все пропущенные занчения заменим на False , то апартаментов 0,2%. Проверим на реальность: https://www.novostroy-spb.ru/novosti/apartamenty_zanyali_desyatuyu_chast к концу 2019 апартментов среди всех новостроек в СПб около 10%. Но в data не только новостройки, но и вторичка. Значит цифра может быть реальной. И обычно владельцы апартаментов указывают этот параметр, т к он принципиален из-за размера коммуналки и невозможности прописаться. Позволим себе заменить пропуски на False

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# #### Квартира-студия - studio

# %% [markdown]
# Пропусков нет. Посмотрим, какие данные есть

# %%
data['studio'].value_counts()
# Out:
# False    23549
# True       149
# Name: studio, dtype: int64

# %% [markdown]
# Данные выглядят корректно, оставляем без изменений

# %% [markdown]
# #### Cвободная планировка - open_plan

# %% [markdown]
# Пропусков нет. Посмотрим, какие данные есть

# %%
data['open_plan'].value_counts()
# Out:
# False    23631
# True        67
# Name: open_plan, dtype: int64

# %% [markdown]
# Данные выглядят корректно, оставляем без изменений

# %% [markdown]
# #### Площадь кухни - kitchen_area

# %% [markdown]
# Пропусков около 2 тыс. Не будем заполнять пропуски, т к самое главное - общая площадь указана

# %%
data['kitchen_area'].hist(bins = 50)

plt.xlabel('Площадь кухни')
plt.ylabel('Количество объявлений')
plt.title('Распределение площади кухни')
plt.show()

# %%
data['kitchen_area'].describe()
# Out:
# count    21420.000000
# mean        10.568410
# std          5.902034
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Данные выглядят реалистично. По гистограмме видно, что есть небольшое количество значений, стремящихся к нулю (в описании видно, что это значение 1.3 кв м). И больше всего кухонь плрщадью около 12 кв м. Совсем маленькие кухни могут быть частью студий. Проверим эту гипотезу

# %%
data[data['kitchen_area'] < 3].pivot_table(index = 'kitchen_area', values = ('studio', 'total_area'))
# Out:
#               studio  total_area
# kitchen_area
# 1.30             0.0   28.500000
# 2.00             0.0   23.712857
# 2.30             0.0   34.700000
# 2.40             0.0   18.400000
# 2.89             0.0   66.400000

# %% [markdown]
# Все квартиры с кухней до 3 метров - не студии, и средняя общая площадь достигает 66 кв м. Проверим нет ли площади кухни больше, чем общей площади

# %%
data[data['kitchen_area'] > data['total_area']]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Площади кухни больше общей площади нет

# %% [markdown]
# Посчитаем медиану площади кухни:

# %%
median_kitchen_area = data['kitchen_area'].median()
median_kitchen_area
# Out:
# 9.1

# %% [markdown]
# Медианы общей площади мы посчитали ранее, выведем, чтобы вспомнить

# %%
median_total_area
# Out:
# 52.0

# %% [markdown]
# Посчитаем соотношение медианы общей площади к медиане площади кухни

# %%
ratio_median_total_kitchen = median_total_area/median_kitchen_area
ratio_median_total_kitchen
# Out:
# 5.714285714285714

# %% [markdown]
# Заполним пропуски отношением общей площади к соотношению, найденному выше

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(data['total_area']/ratio_median_total_kitchen)

# %% [markdown]
# #### Число балконов - balcony

# %% [markdown]
# Пропусков около 11 тыс. Так как пропуски могут значит отсутвие балкона, заменим пропуски на ноль

# %%
data['balcony'] = data['balcony'].fillna(0)

# %%
data['balcony'].hist()

plt.xlabel('Количество балконов')
plt.ylabel('Количество объявлений')
plt.title('Распределение количества балконов')
plt.show()

# %%
data['balcony'].describe()
# Out:
# count    23698.000000
# mean         0.591105
# std          0.959311
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          5.000000
# Name: balcony, dtype: float64

# %% [markdown]
# Больше всего квартир без балконов. И совсем мало квартир с 3 балконами и более

# %% [markdown]
# #### Название населённого пункта - locality_name

# %% [markdown]
# Пропусков около 40. Место расположения считаем важной информацией,  а т к пропусков немного, то удалим их, Заодно сразу выведем уникальные значения, чтобы разобраться с неявными дубликатами

# %%
data = data.dropna(subset =['locality_name'])
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %% [markdown]
# Заменим "посёлок", "посёлок городского типа", "поселок городского типа", "городской поселок", "поселок станции", "поселок при железнодорожной станции" на просто "поселок". Садоводческие товарищества и коттеджные поселки трогать не будем, т к после поиска в интернете считаем, что это отдельные населенные пункты, у которых нет неявного дубликата

# %%
data['locality_name'] = data['locality_name'].str.replace('посёлок', 'поселок')
data['locality_name'] = data['locality_name'].str.replace('посёлок городского типа', 'поселок')
data['locality_name'] = data['locality_name'].str.replace('поселок городского типа', 'поселок')
data['locality_name'] = data['locality_name'].str.replace('городской поселок', 'поселок')
data['locality_name'] = data['locality_name'].str.replace('поселок станции', 'поселок')
data['locality_name'] = data['locality_name'].str.replace('поселок при железнодорожной станции', 'поселок')
print(data['locality_name'].sort_values().unique())
# Out:
# ['Бокситогорск' 'Волосово' 'Волхов' 'Всеволожск' 'Выборг' 'Высоцк'
#  'Гатчина' 'Зеленогорск' 'Ивангород' 'Каменногорск' 'Кингисепп' 'Кириши'
#  'Кировск' 'Колпино' 'Коммунар' 'Красное Село' 'Кронштадт' 'Кудрово'
#  'Лодейное Поле' 'Ломоносов' 'Луга' 'Любань' 'Мурино' 'Никольское'
#  'Новая Ладога' 'Отрадное' 'Павловск' 'Петергоф' 'Пикалёво' 'Подпорожье'
#  'Приморск' 'Приозерск' 'Пушкин' 'Санкт-Петербург' 'Светогорск'
#  'Сертолово' 'Сестрорецк' 'Сланцы' 'Сосновый Бор' 'Сясьстрой' 'Тихвин'
#  'Тосно' 'Шлиссельбург' 'деревня Агалатово' 'деревня Аро' 'деревня Батово'
#  'деревня Бегуницы' 'деревня Белогорка' 'деревня Большая Вруда'
#  'деревня Большая Пустомержа' 'деревня Большие Колпаны'
#  'деревня Большое Рейзино' 'деревня Большой Сабск' 'деревня Бор'
#  'деревня Борисова Грива' 'деревня Ваганово' 'деревня Вартемяги'
#  'деревня Вахнова Кара' 'деревня Выскатка' 'деревня Гарболово'
#  'деревня Глинка' 'деревня Горбунки' 'деревня Гостилицы'
# ...

# %% [markdown]
# #### Расстояние до ближайшего аэропорта в метрах (м) - airports_nearest

# %%
data['airports_nearest'].hist()

plt.xlabel('Расстояние до аэропорта')
plt.ylabel('Количество объявлений')
plt.title('Распределение удаленности от аэропорта')
plt.show()

# %%
data.query('airports_nearest < 5000')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 21085             0   7000000.0        34.7           2018-09-23      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 21085             2.7           9.0    19.799999      3         False  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 21085           6.0      2.0  Санкт-Петербург               0.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 21085             22801.0               0.0            NaN               0.0
#
#        ponds_nearest  days_exposition
# 21085            NaN             60.0
#
# [1 rows x 22 columns]

# %% [markdown]
# Гистограмма выглядит стадартной. Есть одно значение, где расстояние до аэропорта меньше 5000 м и равно 0. Явно ошибка. Заменим этот ноль на пропуск

# %%
data.loc[21085,'airports_nearest'] = None

# %%
data.pivot_table(index = 'locality_name', values = 'airports_nearest', 
                      aggfunc = ('median', 'mean')).sort_values(by = 'median')
# Out:
#                                  mean   median
# locality_name
# поселок Александровская  12896.500000  12896.5
# Пушкин                   16447.869919  15766.0
# поселок Шушары           16061.458716  17427.0
# Павловск                 21053.342105  20529.5
# поселок Петро-Славянка   20605.000000  20605.0
# Красное Село             26595.579545  25715.5
# поселок Металлострой     25726.484848  25758.0
# Колпино                  26375.863501  26232.0
# поселок Усть-Ижора       26510.500000  26510.5
# Санкт-Петербург          28047.444480  26757.5
# поселок Стрельна         28148.363636  28317.0
# поселок Понтонный        30581.400000  30642.0
# поселок Сапёрный         34142.666667  34147.5
# Петергоф                 40184.676617  39231.0
# Ломоносов                48308.280303  48415.5
# поселок Мурино           51553.000000  51553.0
# поселок Левашово         52693.000000  52693.0
# поселок Парголово        53994.926606  53426.0
# поселок Песочный         54565.500000  54831.5
# ...

# %% [markdown]
# Свели таблицу по названию населенных пунктов и расстоянию до аэропорта. Видим, что данные о расстоянии до аэропорта есть только у части населенных пунктов. По остальным нечем заполнять пропуски. Оставляем , как есть

# %% [markdown]
# #### Расстояние до центра города (м) - city_centers_nearest

# %% [markdown]
# Исправим название

# %%
data.rename(columns={'cityCenters_nearest': 'city_centers_nearest'}, inplace=True)

# %%
data['city_centers_nearest'].hist()

plt.xlabel('Расстояние до центра города')
plt.ylabel('Количество объявлений')
plt.title('Распределение удаленности от центра города')
plt.show()

# %%
data['city_centers_nearest'].describe()
# Out:
# count    18138.000000
# mean     14198.137612
# std       8606.986784
# min        181.000000
# 25%       9241.000000
# 50%      13106.000000
# 75%      16293.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# Максимальное расстояние 66 км - похоже на правду, минимальное - 0 тоже. Значения медианы и среднего близкие. По гистограмме не видно выбивающихся значений

# %% [markdown]
# #### Число парков в радиусе 3 км - parks_around_3000

# %% [markdown]
# Поправим название:

# %%
data.rename(columns={'parks_around3000': 'parks_around_3000'}, inplace=True)

# %%
data['parks_around_3000'].hist()

plt.xlabel('Число парков в радиусе 3 км')
plt.ylabel('Количество объявлений')
plt.title('Распределение количества парков в радиусе 3 км')
plt.show()

# %% [markdown]
# Данные выглядят корректными. Больше всего парков - 0, но не больше 3-х в пределах ближайших 3 км.

# %% [markdown]
# #### Расстояние до ближайшего парка (м) - parks_nearest

# %%
data['parks_nearest'].hist()

plt.xlabel('Расстояние до ближайшего парка, м')
plt.ylabel('Количество объявлений')
plt.title('Распределение близости парков')
plt.show()

# %%
data['parks_nearest'].describe()
# Out:
# count    8063.000000
# mean      490.791765
# std       342.557759
# min         1.000000
# 25%       288.000000
# 50%       454.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Среднее и медианное значение почти совпадают и составляют 450, 490 м. Данные о наличии парков заполняются автоматически по геоданным. Если адрес указан верно, то система тоже должна посчитать верно. Те объявления, где указан 0, могут означать, что рядом с адресом находится сквер или другая небольшая зеленая зона, а система посчитала сквер полноценным парком. Также 0 может относиться к загорорным объектам недвижимости, расположенным в коттеджных поселках и садовых товариществах

# %% [markdown]
# #### Число водоёмов в радиусе 3 км - ponds_around_3000

# %% [markdown]
# Исправим название столбца

# %%
data.rename(columns={'ponds_around3000': 'ponds_around_3000'}, inplace=True)

# %%
data['ponds_around_3000'].hist()

plt.xlabel('Число водоемов в радиусе 3 км')
plt.ylabel('Количество объявлений')
plt.title('Распределение количества водоемов в радиусе 3 км')
plt.show()

# %% [markdown]
# Данные выглядят корректными. Больше всего парков - 0, но не больше 3-х в пределах ближайших 3 км. Также, как и парков. Это логчно, т к обычно водоем находится внутри зеленой зоны

# %% [markdown]
# #### Расстояние до ближайшего водоёма (м) - ponds_nearest

# %%
data['ponds_nearest'].describe()
# Out:
# count    9085.000000
# mean      518.059879
# std       277.841733
# min        13.000000
# 25%       293.000000
# 50%       502.000000
# 75%       730.000000
# max      1344.000000
# Name: ponds_nearest, dtype: float64

# %% [markdown]
# Данные выглядят корректными - средняя и медиана совпадают. Много пропусков, но расстояние до водоема не может быть основной информацией для всех обхектов. Большее значение может иметь для загорода, но в самом городе - это не самый главный параметр

# %% [markdown]
# #### Вывод

# %% [markdown]
# Изучили столбцы датасета.
# - Цены указаны без пропусков. Нереалистичное значение 12 тыс за объект удалили. Предплогает, что в данном объекте была добпущена ошибка. Среднее и медианное значения сильно отличаются и составляют 6,5 и 4,6 млн. Самый дорогой объект 763 млн - отличается от ближайшего примерно на 300 млн и влияет на разницу между средней и медианой
# - Общая площадь. Без пропусков. Диапозон от 12 кв м до 900 кв м. Данные оставили без изменений
# - Дата публикации. Изменили тип данных c object на datetime. Видим, что объявления представлены примерно за 5 лет
# - Количество комнат. 75% квартир имеют не более 3 комнта. Среднее и медианное значение - 2. Максимальное - 19. Не удаляли данные, т к 19 комнат не влияют на среднее или медиану по количеству комнат.
# - Высота потолков. Исправили ошибки. Значения выше 14 метро разделили на 10, т к предположили ошибку при заполнении объявления
# - Этажей в доме. Удалили два нереалистичных значения - объекты выше 37 этажей
# - Жилая площадь. Средняя и медиана составляют около 30 кв м. 75% объектов не более 42 кв м. Максимальная жилая площадь = 409 кв м.
# - Апартаменты. Предположили, что пропуски = False, т к апартаментов на рынке недвижимости меньшинство. А также предплоложили, что если бы объект являлся апартаментами, это не забыли бы заполнить. Пропуски заменили на False
# - Студия. Пропусков нет, данные выглядят корректно
# - Площадь кухни. Среднее и медианное значения почти совпадают и составляют 10 и 9 метров. Есть значения кухонь менее 3 метров. Это может быть связано, с тем, что люди при заполненнии не проверяют точные данные, заполняют на глаз и по чертежам, к кухне, действительно относится небольшой участок.
# - Число балконов. Заполнили пропуски нулями. 75% объектов имеют не более 1 балкона, максимальное значние - 5
# - Название населенного пункта. Удалили пропуски (около 40), удалили неявные дубликаты
# - Расстояние до ближайшего аэропорта. Удалили значение менее 5 км. Остальные данные распределены правдоподобно относительно диаметра города
# - Большинство квартир продается в диапозоне от 10 до 20 км от центра города. Максимальное значение 66 км может соответствовать удаленности населенных пунктов в области
# - Число парков и водоемов в радиусе 3 км. У большинства объектов в радиусе 3 км - 0 парков  и водоемов. У остальных о не более 3.
# - Максимальное расстояние до ближайшего водоема и парка отличается и составляет 1 и 3 км соответсвенно. Есть объекты практически находящиеся в парках, что может быть обусловлено расположением в области и некорретным отображением системой геоданных

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23649 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23649 non-null  int64
#  1   last_price            23649 non-null  float64
#  2   total_area            23649 non-null  float64
#  3   first_day_exposition  23649 non-null  datetime64[ns]
#  4   rooms                 23649 non-null  int64
#  5   ceiling_height        23649 non-null  float64
#  6   floors_total          23562 non-null  float64
#  7   living_area           23649 non-null  float32
#  8   floor                 23649 non-null  int64
#  9   is_apartment          23649 non-null  bool
#  10  studio                23649 non-null  bool
#  11  open_plan             23649 non-null  bool
#  12  kitchen_area          23649 non-null  float64
#  13  balcony               23649 non-null  float64
# ...

# %% [markdown]
# #### Добавим колонку с ценой одного квадратного метра

# %%
data['price_square_meter'] = data['last_price'] / data['total_area']

# %% [markdown]
# #### Добавим колонки с годом, месяцем и днем размещения объявления

# %%
data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year

# %%
data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month

# %%
days = {0:"пн", 1:"вт", 2:"ср", 3:"чт", 4:"пт", 5:"сб", 6:"вс"}

# %%
data['day'] = data['first_day_exposition'].dt.dayofweek.map(days)

# %% [markdown]
# #### Добавим колонку с типом этажа объекта

# %%
def type_floor(df):
    if df['floor'] == 1:
       return 'первый'
    elif df['floor'] == df['floors_total']:
       return 'последний'
    return 'другой'

data['type_floor'] = data.apply(type_floor, axis=1)

# %% [markdown]
# #### Добавим колонку с расстоянием от центра города в км

# %%
data['city_centers_nearest_km'] = data['city_centers_nearest']/1000
data['city_centers_nearest_km'] = np.round( data['city_centers_nearest_km'] )

# %% [markdown]
# Выведем обновленную таблицу

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0    51.000000      8         False  ...
# 1            2.65          11.0    18.600000      1         False  ...
# 2            2.65           5.0    34.299999      4         False  ...
# 3            2.65          14.0    91.730766      9         False  ...
# 4            3.03          14.0    32.000000     13         False  ...
#
#    parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# ...

# %% [markdown]
# Вывод: Мы подготовили данные для изучения зависимостей. В том числе для изучения зависимости цены  кв м от центра города и даты размещения объявления

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %%
data.hist(figsize=(15, 20))

plt.show()

# %% [markdown]
# Вывели гистограммы еще раз. Посмотрим какие произошли изменения после предобработки:
# 1. за счет удаления нереалистично больших значений общего количества этажей в доме, гисторграмма floors_total стала больше похожей на стандартное распределение.
# 2. выделилось преобладание нулевого количества балконов
# 3. ушло нулевое значение в гистограмме airports_nearest
# 4. появились гистограммы с добавленными столбцами и датой публикации, в которой изменили тип данных:
# - Видно, что больше всего объявлений выложено в 2017 и 2018 годах, меньше всего в 2014 - это логично, т к первое объявление из датасета - ноябрь 2014
# - Количество выкладываемых объявлений резко падает в мае, явно выростает с осени. Объяснимо тем, что летом люди уезжают в отпуска

# %% [markdown]
# #### Продолжительность размещения объявления days_exposition

# %% [markdown]
# У большинства объявлений есть срок размещения. Пропусков около 3000. Есть вероятность, что кто-то передумывает продавать квартиры и снимает с размещения. Но определить таких нет возможность и предположительно их мало. Поэтому считаем, что снятие с объявления = продажа.

# %%
data['days_exposition'].describe()
# Out:
# count    20469.000000
# mean       180.761640
# std        219.779967
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Медианное значение 95 дней. Большинство квартир (75%) продавались меньше, чем за год (231 день = около 8 месяцев).
#
# Но среднее в два раза больше = примерно 181 день. А также есть очень большое максильмаон значение = 1580 дней, это больше 4 лет.

# %%
data.boxplot('days_exposition')

plt.ylabel('Число дней размещения')
plt.title('Диаграмма размаха продолжительности размещения объявления')
plt.show()

# %%
data['days_exposition'].hist(bins=10)
plt.xlabel('Число дней размещения')
plt.ylabel('Количество объявлений')
plt.title('Распределение продолжительности размещения объявления')
plt.show()
data['days_exposition'].hist(bins=100)
plt.xlabel('Число дней размещения')
plt.ylabel('Количество объявлений')
plt.title('Распределение продолжительности размещения объявления')
plt.show()

# %% [markdown]
# И по гистрограммам и по диаграмме размаха видно, что объекты, которые продавались больше примерно 500 дней - продавались нетипично долго. Посмотрим зависимость продажи срока продажи квартиры от цены:

# %%
data.plot(x='last_price', y='days_exposition', kind='scatter', alpha=0.4) 

plt.xlabel('Цена на момент снятия с публикации')
plt.ylabel('Число дней размещения объявления')
plt.title('Зависимость скорости продажи от цены')
plt.show()

# %% [markdown]
# Не видим очевидную зависимость скорости продажи квартиры от цены. Возможно, квартиры долго стоят в продаже по другим причинам: несоответствие цена-качество, юридические причины - возможность или нет купить объектв ипотеку. Но также высока вероятность, что про объявления забывали. Без обновлений они падали в рейтинге и хозяина квартиры покупатели не беспокоили звонками, напоминая тем самым, что объявление до сих пор активно

# %% [markdown]
# #### Зависимость цены от общей площади квартиры

# %%
data.plot(x='total_area', y='last_price', kind='scatter', alpha=0.4) 

plt.xlabel('Общая площадь')
plt.ylabel('Цена на момент снятия с публикации')
plt.title('Зависимость цены от общей площади квартиры')
plt.show()

# %%
data['total_area'].corr(data['last_price'])
# Out:
# 0.6538081893676135

# %% [markdown]
# Коэффициент корреляции = 0,65 находится в середине между 0 и единицей, но ближе к 1. Зависимость цены от общей площади есть, но не прямая. Так как есть и другие факторы - в первую очередь расположение. Это логично, т к квартира с одной и той же площадью стоит по разному в центре и в спальном районе. Возможно, нужно рассматривать населенные пункты и районы СПб по отдельности

# %% [markdown]
# #### Зависимость цены от жилой площади квартиры

# %%
data.plot(x='living_area', y='last_price', kind='scatter', alpha=0.4) 

plt.xlabel('Жилая площадь')
plt.ylabel('Цена на момент снятия с публикации')
plt.title('Зависимость цены от жилой площади квартиры')
plt.show()

# %%
data['living_area'].corr(data['last_price'])
# Out:
# 0.5859381668862528

# %% [markdown]
# Коэффициент корреляции меньше, чем в при зависимости от общей площади. Но не намного. Равен 0,56. Вероятно, разница не большая, т к общая площадь имеет большее значение. А также общая площадь указывается корректно по чертежам, а в понимание, что считать жилым могут быть различия. Например, кухня-гостинная может считаться кухней, в то время, как в ней можно поставить и диван, чтобы спать

# %% [markdown]
# #### Зависимость цены от площади кухни

# %%
data.plot(x='kitchen_area', y='last_price', kind='scatter', alpha=0.4) 

plt.xlabel('Площадь кухни')
plt.ylabel('Цена на момент снятия с публикации')
plt.title('Зависимость цены от площади кухни')
plt.show()

# %%
data['kitchen_area'].corr(data['last_price'])
# Out:
# 0.5148570003579624

# %% [markdown]
# Зависимость цены почти такая же, как у жилой площади. Площадь квартиры и ее частей не является единственным важным фактором при формировании цены

# %% [markdown]
# #### Зависимость цены от количества комнат

# %%
data.plot(x='rooms', y='last_price', kind='scatter', alpha=0.4) 

plt.xlabel('Количество комнат')
plt.ylabel('Цена на момент снятия с публикации')
plt.title('Зависимость цены от количества комнат')
plt.show()

# %%
data['rooms'].corr(data['last_price'])
# Out:
# 0.36342176653077163

# %% [markdown]
# Судя по коэффициенту корреляции зависимость стремится  к нулю. По графику видно, что цена растет до 5 комнат, а далее идет на спад. При этом среди дешевых квартир есть все варианты; 0, 1, 2, 3, 4, 5 комнат. Когда мы исследовали колонку с количеством комнат, то увидели, что 75% квартир имеет не более 3 комнат. Вероятно, квартиры с большим количеством комнат имеют больше особенностей влияющих на цену, они не так массовы. Может, это целый этаж с хорошим ремонтом в центре Петербурга или 6 комнатная видовая квартира около залива. Или коммуналка в плохом состоянии с неудобной планировкой

# %% [markdown]
# #### Зависимость цены от типа этажа квартиры

# %%
data.plot(x='type_floor', y='last_price', kind='scatter', alpha=0.4) 

plt.xlabel('Тип этажа квартиры')
plt.ylabel('Цена на момент снятия с публикации')
plt.title('Зависимость цены от типа этажа квартиры')
plt.show()

# %%
data['floor'].corr(data['last_price'])
# Out:
# 0.026878477351358662

# %%
data.pivot_table(index='type_floor', values = 'last_price', aggfunc = 'median')
# Out:
#             last_price
# type_floor
# другой       4850000.0
# первый       3900000.0
# последний    4300000.0

# %% [markdown]
# Из графика видно, что самые дорогие квартиры продавались на последних этажах. Похоже, что это несколько частных случаев. Сводная таблица показала, что самая высокая медиана цены у типа "другой", далее идет "последний" этаж и самые дешевые объекты на первом этаже.
#
# Это закономерно, так как первый этаж может быть более подвержен кражам, на нем слышнее шум с улицы и ближе выхлоп от машин. Недостатками последнего этажа могут быть нагрев летом от крыши или близость чердака.

# %% [markdown]
# #### Зависимость цены от даты размещения

# %%
data.plot(x='year', y='last_price', kind='scatter', alpha=0.4) 

plt.xlabel('Год размещения')
plt.ylabel('Цена на момент снятия с публикации')
plt.title('Зависимость цены от года размещения объявления')
plt.show()

# %%
data['year'].corr(data['last_price'])
# Out:
# -0.04288981845193528

# %% [markdown]
# Зависомость цены от года размещения объявления практически нулева. Но мы видим, что самые дорогие квартиры были проданы в 2017 году. В 2014 было меньше всего объявлений, т к первое объявление в датасете размещено в ноябре 2014 года

# %%
data.plot(x='month', y='last_price', kind='scatter', alpha=0.4) 

plt.xlabel('Месяц размещения')
plt.ylabel('Цена на момент снятия с публикации')
plt.title('Зависимость цены от месяца размещения объявления')
plt.show()

# %%
data['month'].corr(data['last_price'])
# Out:
# 0.0027164190592474636

# %% [markdown]
# Также нет зависимости цены квартиры от месяца размещения объявления.

# %%
data.plot(x='day', y='last_price', kind='scatter', alpha=0.4) 

plt.xlabel('День недели размещения')
plt.ylabel('Цена на момент снятия с публикации')
plt.title('Зависимость цены от дня недели размещения объявления')
plt.show()

# %% [markdown]
# Не видно зависимости цены квартиры от дня недели размещения объявления

# %% [markdown]
# #### Цена квадратного метра в зависимости от населенного пункта

# %%
data['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург      15720
# поселок Мурино         556
# поселок Шушары         440
# Всеволожск             398
# Пушкин                 369
# Колпино                338
# поселок Парголово      327
# Гатчина                307
# деревня Кудрово        299
# Выборг                 237
# Name: locality_name, dtype: int64

# %%
meter_price_by_loc = data.groupby('locality_name')\
            .agg({'price_square_meter': 'mean', 'locality_name': 'count'})\
            .rename({'locality_name': 'n_records'}, axis=1).sort_values('n_records', ascending=False).head(10)
meter_price_by_loc
# Out:
#                    price_square_meter  n_records
# locality_name
# Санкт-Петербург         114856.307596      15720
# поселок Мурино           85681.762601        556
# поселок Шушары           78677.364217        440
# Всеволожск               68654.473986        398
# Пушкин                  103125.819291        369
# Колпино                  75424.579098        338
# поселок Парголово        90175.913458        327
# Гатчина                  68746.146763        307
# деревня Кудрово          92473.547576        299
# Выборг                   58141.909153        237

# %%
meter_price_by_loc.sort_values('price_square_meter',ascending=False)
# Out:
#                    price_square_meter  n_records
# locality_name
# Санкт-Петербург         114856.307596      15720
# Пушкин                  103125.819291        369
# деревня Кудрово          92473.547576        299
# поселок Парголово        90175.913458        327
# поселок Мурино           85681.762601        556
# поселок Шушары           78677.364217        440
# Колпино                  75424.579098        338
# Гатчина                  68746.146763        307
# Всеволожск               68654.473986        398
# Выборг                   58141.909153        237

# %% [markdown]
# Из 10 населенных с самым большим количеством объявлений, самая высокая средняя цена за квадратный метр 114 тыс в Санкт-Петербурге. Самая низкая цена в Выборге = 58 тыс

# %% [markdown]
# #### Средняя цена км по удаленности от центра города

# %%
spb = data[data['locality_name'] == 'Санкт-Петербург']
spb.plot(x='city_centers_nearest_km', y='price_square_meter', kind='scatter', alpha=0.1) 

plt.xlabel('Количество км от центра города')
plt.ylabel('Цена за кв. м')
plt.title('Зависимость цены  за кв. м. от удаленности от центра города')
plt.show()

# %%
(spb.pivot_table(index = 'city_centers_nearest_km',values = 'price_square_meter',
                 aggfunc = ('median', 'mean')).sort_values(by = 'median', ascending = False).reset_index())
# Out:
#     city_centers_nearest_km           mean         median
# 0                       0.0  245833.530289  172619.047619
# 1                      27.0  132115.709459  132115.709459
# 2                       6.0  151012.193621  131835.227273
# 3                       1.0  177005.407676  128485.110056
# 4                       5.0  140509.789046  127093.283865
# 5                       7.0  156176.879664  127017.083563
# 6                       2.0  157849.007329  123035.513418
# 7                       8.0  125671.442742  122944.928910
# 8                       4.0  133282.874761  117952.262904
# 9                       3.0  121387.453704  108469.112355
# 10                     10.0  112727.516925  106451.612903
# 11                      9.0  113321.952734  105817.029654
# 12                     13.0  108148.127854  104081.632653
# 13                     12.0  107488.734023  103988.603989
# 14                     20.0  103045.181922  103703.693333
# ...

# %%
spb.query('city_centers_nearest_km == 27')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 748             13  14350000.0        74.0           2017-11-28      2
# 5961             6   2250000.0        32.0           2018-02-27      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 748             3.13           5.0         30.0      3         False  ...
# 5961            2.65           2.0         16.5      2         False  ...
#
#       parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# 748          1496.0                0.0            NaN            128.0
# 5961            NaN                0.0            NaN            178.0
#
#      price_square_meter  year  month  day  type_floor  city_centers_nearest_km
# 748       193918.918919  2017     11   вт      другой                     27.0
# 5961       70312.500000  2018      2   вт   последний                     27.0
#
# [2 rows x 28 columns]

# %% [markdown]
# Выделили объекты относящиеся только к Санкт-Петербургу. На графике и в сводной таблице использовали стоимость квадратного метра.
# - Видно, что в самом центре (там где км = 0) продается не так много квартир. Но все же в центре самое высокое медианное значение стоимости кв м. То есть жилья мало и оно дорогое.
# - Цены на квартиры в центре (1-8 км от центра) наиболее дорогие, за исключением объекотов на расстоянии 3 км (просадка в 3 км видна и по графику, и по таблице)
# - После 9-10 км цены постепенно падают
# - Неожиданно в сводной таблице на втором месте по стоимости идет расстояние в 27 км, поэтому посмотрели, сколько там квартир. Увидели, что их всего две и одна из них в 2,7 раз дороже второй. По двум квартирам не корректно делать вывод, что на расстоянии 27 км - вторые по стоимости квартиры в СПб. Похоже, среднее значние там должно быть примерно, как 28-29 км

# %% [markdown]
# #### Вывод

# %% [markdown]
# - Нет прямой зависимости цены объекта от его общей, жилой площади, а также площади кухни. Коэффициент корреляции у эти параметров равен примерно 0,5-0,6. На стоимость влияют и другие факторы. Например, расположение.
# - Нет зависимости цены квартиры от количества балконов
# - Цена зависит от количества комнат еще меньше, чем от площади квартиры и составяет примерно 0,36.
# - Цена не зависит от года, дня и месяца размещения объявления, но самые дорогие квартиры были проданы в 2017 году
# - Стоимость квадратного метра уменьшается с удаленностью от центра города

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Мы изучили датасет из более чем 23 тыс позиций. В нем были данные по объектам, расположенные в Санкт-Петербурге и Ленинградской области, в том числе в коттеджных поселках и садоводческих товариществах.
#
# У большинства были заполнены самые важные значения : название населенного пункта, общая площадь, цена, количество комнат. Видно, что основные параметры, по которым обычно принимают решение о покупке квартиры, заполняются корректно, либо при заполнении объявления есть форма не позволяющая пропустить значение. Также, даже если в объявлении допущена ошибка, можно предположить, что она корректируется в процессе размещения.
#
# Были удалены строки с пропусками, обработаны неявные дубликаты  в названиях населенных пунктов. Исправлены некорректные значения в количестве балконов. Заполнены пропуски в высоте потолков, жилой площади и площади кухни.
# В датасете обнаружены незаполненные значения по геоданным: про количество и расположение прудов и парков. Вероятно система не нашла их на карте в необходимом радиусе и оставила пропуски.
#
# Были рассчитаны дополнительные значения для анализа - расстояние от центра в км, стоимость кв м, год, месяц, день размещения объявления
#
# После обработки информации было достаточно для исследования.
# Самые дорогие объекты находятся в Санкт-Петербурге, а также есть явная зависимость цены кв метра от его расположения относительно центра города. Несколько просели по цене квартиры в центре на расстоянии 3 км.
#
# Засимость цены объекта от площади квартиры не прямая и коэффициент коррекляции составляет примерно 0,6. Можем сделать вывод, что также большое значение имеет расположение объекта.
#
# Мединная стоимость квартир с типом "другой" выше, чем у объектов на последнем этаже. Самые дешевые квартиры на первом.
#
# Не обнаружено зависимости цены квартиры от количества балконов.
#
#
# Также был изучен параметр - сколько дней объявление было не снято с продажи. Медианное значение составляет 95 дней. Есть объявления, которые вероятно забыли снять с публикации, т к срок составляет окоо 4 лет
